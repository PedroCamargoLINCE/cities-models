# %% [markdown]
# # GRU Multivariado (Soma das Próximas 4 Semanas)
#
# Este notebook implementa o modelo GRU multivariado para previsão da **soma das próximas 4 semanas** (previsão mensal) das taxas de morbidade respiratória em municípios brasileiros, utilizando variáveis externas.
#
# - **Modelo:** GRU com Features Externas
# - **Alvo:** Soma das próximas 4 semanas (previsão mensal)
# - **Input:** sequência de 24 semanas × N features (shape: [batch, 24, N])
# - **Arquitetura:** GRU(64) → Dense(1)
# - **Normalização:** Z-score por feature
# - **Perda:** MAE ou Huber
# - **Todo o código é modular e importado dos módulos `src/`.**

# %%
import sys
import os

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"Project root: {project_root}")

# Add the project root to sys.path (not the src directory)
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"Added {project_root} to sys.path")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from src.preprocessing import load_city_data, prepare_data_for_model, filter_city, clean_timeseries
from src.models import build_gru_multivariate
from src.train import train_model, evaluate_model, generate_forecasts, save_predictions, save_metrics
from src.utils import plot_forecast, plot_forecast_error, plot_training_history

results_dir = os.path.join('results', 'gru_multivariate')
os.makedirs(results_dir, exist_ok=True)

np.random.seed(42)
# Out:
# Project root: c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models
# Added c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models to sys.path

# %% [markdown]
# ## Estrutura do Repositório
#
# - **data/**: Um CSV por cidade, cada um com coluna de data, coluna alvo e features opcionais.
# - **notebooks/**: Notebooks para cada experimento. Apenas visualização e exploração.
# - **src/**: Módulos reutilizáveis:
#     - `preprocessing.py`: Carregamento, normalização, split, criação de janelas
#     - `models.py`: Definições de modelos (baselines, MLP, GRU, etc.)
#     - `train.py`: Rotinas de treino e avaliação
#     - `utils.py`: Funções auxiliares (plot, métricas, etc.)
# - **results/**: Previsões e métricas salvas.
# - **instructions.md**: Guia de boas práticas.
#
# **Toda a lógica central está em `src/`.**

# %% [markdown]
# ## Carregamento e Exploração dos Dados
#
# Carregue os dados de morbidade respiratória para análise. Você pode iterar sobre todas as cidades ou selecionar uma específica.

# %%
# Exemplo: Carregar dados de uma cidade (ajuste o caminho conforme necessário)
data_path = '../data/df_base_morb_resp.csv'
df = load_city_data(data_path)

print(f"Formato do dataset: {df.shape}")
df.head()
# Out:
# Formato do dataset: (6684000, 11)
#     CD_MUN  week    target      PIB      DENS       URB         CO2  \
# 0  1100015     0  0.515856  3469.14  3.541043  0.000611  550.985905
# 1  1100015     1  0.539765  3469.14  3.541043  0.000611  550.985905
# 2  1100015     2  0.458823  3469.14  3.541043  0.000611  550.985905
# 3  1100015     3  0.485555  3469.14  3.541043  0.000611  550.985905
# 4  1100015     4  0.231805  3469.14  3.541043  0.000611  550.985905
#
#          CH4       N2O        LAT    LON
# 0  92.946598  6.657747 -12.883213 -62.39
# 1  92.946598  6.657747 -12.883213 -62.39
# 2  92.946598  6.657747 -12.883213 -62.39
# 3  92.946598  6.657747 -12.883213 -62.39
# 4  92.946598  6.657747 -12.883213 -62.39

# %%
print("Colunas disponíveis:")
print(df.columns.tolist())
df.describe()
# Out:
# Colunas disponíveis:
# ['CD_MUN', 'week', 'target', 'PIB', 'DENS', 'URB', 'CO2', 'CH4', 'N2O', 'LAT', 'LON']
#              CD_MUN          week        target           PIB          DENS  \
# count  6.684000e+06  6.684000e+06  6.684000e+06  6.003816e+06  6.033600e+06
# mean   3.253591e+06  5.995000e+02  4.710729e-01  1.397299e+04  8.091379e+01
# std    9.848220e+05  3.464101e+02  3.616928e+00  1.973538e+04  3.952444e+02
# min    1.100015e+06  0.000000e+00  0.000000e+00 -1.459830e+03  3.143629e-02
# 25%    2.512101e+06  2.997500e+02  0.000000e+00  4.516650e+03  1.112562e+01
# 50%    3.146280e+06  5.995000e+02  0.000000e+00  8.607535e+03  2.363456e+01
# 75%    4.119202e+06  8.992500e+02  2.773210e-01  1.684539e+04  4.817254e+01
# max    5.300108e+06  1.199000e+03  7.359496e+02  9.208340e+05  1.344249e+04
#
#                 URB           CO2           CH4           N2O           LAT  \
# count  6.033600e+06  6.033600e+06  6.033600e+06  6.033600e+06  6.033600e+06
# mean   1.268524e-02  3.953797e+04  7.463403e+02  1.116126e+01 -1.638302e+01
# std    4.668693e-02  1.244388e+05  1.332048e+04  2.845796e+01  8.354524e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -3.365254e+01
# 25%    1.319166e-03  4.454221e+03  6.922971e+01  4.712564e+00 -2.279264e+01
# 50%    2.999792e-03  1.128696e+04  1.379897e+02  8.660524e+00 -1.785337e+01
# 75%    7.148583e-03  2.817704e+04  2.405503e+02  1.352129e+01 -8.456431e+00
# max    9.768962e-01  3.137265e+06  7.075641e+05  3.683565e+03  4.685425e+00
#
#                 LON
# count  6.033600e+06
# mean  -4.637996e+01
# std    6.424812e+00
# min   -7.348400e+01
# 25%   -5.102275e+01
# 50%   -4.661550e+01
# 75%   -4.166000e+01
# max   -3.487000e+01

# %% [markdown]
# ## Seleção e Limpeza de Cidade
#
# Selecione uma cidade específica para modelagem e limpe a série temporal.

# %%
# Select city for modeling (set to None to use all cities)
CD_MUN_SELECTED = 3550308  # São Paulo

df_city = filter_city(df, cd_mun=CD_MUN_SELECTED)
df_city = clean_timeseries(df_city, target_column='target')
print(f"Selected city shape: {df_city.shape}")
# Out:
# Selected city shape: (1200, 11)

# %% [markdown]
# ## Pré-processamento
#
# Prepare os dados para o modelo GRU multivariado. O input é uma sequência de 24 semanas × N features.

# %%
# Set the correct target column
model_params = {
    'sequence_length': 12,
    'forecast_horizon': 4,  # Soma das próximas 4 semanas (previsão mensal)
    'normalization': 'zscore',
    'val_size': None
}
target_column = 'target'
features = None  # Use all features except 'CD_MUN' and 'week' by default

data_dict = prepare_data_for_model(
    df=df_city,
    target_column=target_column,
    sequence_length=model_params['sequence_length'],
    forecast_horizon=model_params['forecast_horizon'],
    normalization=model_params['normalization'],
    val_size=model_params.get('val_size', None),
)

X_train = data_dict['X_train']
y_train = data_dict['y_train']
X_val = data_dict.get('X_val', None)
y_val = data_dict.get('y_val', None)
X_test = data_dict['X_test']
y_test = data_dict['y_test']
test_df = data_dict['test_df']
scaler = data_dict.get('scaler')
feature_columns = data_dict.get('feature_columns', None)

# %% [markdown]
# ## Definição e Treinamento do Modelo
#
# O modelo GRU multivariado utiliza uma camada GRU com 64 unidades e uma camada densa de saída.

# %%
input_shape = X_train.shape[1:]
model = build_gru_multivariate(input_shape=input_shape, loss='mae')

history = train_model(
    model=model,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    batch_size=32,
    epochs=300,
    patience=30,
    verbose=1
)
# Out:
# Epoch 1/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2147 - val_loss: 2.1491 - learning_rate: 0.0010
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2147 - val_loss: 2.1491 - learning_rate: 0.0010
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5647 - val_loss: 2.1277 - learning_rate: 0.0010
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5647 - val_loss: 2.1277 - learning_rate: 0.0010
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2919 - val_loss: 2.0756 - learning_rate: 0.0010
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2919 - val_loss: 2.0756 - learning_rate: 0.0010
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2334 - val_loss: 2.0570 - learning_rate: 0.0010
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2334 - val_loss: 2.0570 - learning_rate: 0.0010
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2116 - val_loss: 1.9667 - learning_rate: 0.0010
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2116 - val_loss: 1.9667 - learning_rate: 0.0010
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1268 - val_loss: 1.9617 - learning_rate: 0.0010
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1268 - val_loss: 1.9617 - learning_rate: 0.0010
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1847 - val_loss: 1.9351 - learning_rate: 0.0010
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1847 - val_loss: 1.9351 - learning_rate: 0.0010
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0768 - val_loss: 1.9684 - learning_rate: 0.0010
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0768 - val_loss: 1.9684 - learning_rate: 0.0010
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1250 - val_loss: 1.9172 - learning_rate: 0.0010
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1250 - val_loss: 1.9172 - learning_rate: 0.0010
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0777 - val_loss: 1.9353 - learning_rate: 0.0010
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0777 - val_loss: 1.9353 - learning_rate: 0.0010
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1011 - val_loss: 1.8941 - learning_rate: 0.0010
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1011 - val_loss: 1.8941 - learning_rate: 0.0010
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0581 - val_loss: 1.8961 - learning_rate: 0.0010
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0581 - val_loss: 1.8961 - learning_rate: 0.0010
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1394 - val_loss: 1.9381 - learning_rate: 0.0010
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1394 - val_loss: 1.9381 - learning_rate: 0.0010
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1160 - val_loss: 2.0371 - learning_rate: 0.0010
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1160 - val_loss: 2.0371 - learning_rate: 0.0010
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0748 - val_loss: 2.0012 - learning_rate: 0.0010
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0748 - val_loss: 2.0012 - learning_rate: 0.0010
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0567 - val_loss: 1.9921 - learning_rate: 0.0010
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0567 - val_loss: 1.9921 - learning_rate: 0.0010
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0303 - val_loss: 2.0042 - learning_rate: 0.0010
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0303 - val_loss: 2.0042 - learning_rate: 0.0010
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0642 - val_loss: 1.9491 - learning_rate: 0.0010
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0642 - val_loss: 1.9491 - learning_rate: 0.0010
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0348 - val_loss: 2.0291 - learning_rate: 0.0010
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0348 - val_loss: 2.0291 - learning_rate: 0.0010
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9301 - val_loss: 1.9984 - learning_rate: 0.0010
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9301 - val_loss: 1.9984 - learning_rate: 0.0010
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0351 - val_loss: 2.0622 - learning_rate: 0.0010
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0351 - val_loss: 2.0622 - learning_rate: 0.0010
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0115 - val_loss: 2.0947 - learning_rate: 0.0010
# Epoch 23/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0115 - val_loss: 2.0947 - learning_rate: 0.0010
# Epoch 23/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0039 - val_loss: 2.0533 - learning_rate: 0.0010
# Epoch 24/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0039 - val_loss: 2.0533 - learning_rate: 0.0010
# Epoch 24/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9799 - val_loss: 2.0668 - learning_rate: 0.0010
# Epoch 25/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9799 - val_loss: 2.0668 - learning_rate: 0.0010
# Epoch 25/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0314 - val_loss: 2.0903 - learning_rate: 0.0010
# Epoch 26/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0314 - val_loss: 2.0903 - learning_rate: 0.0010
# Epoch 26/300
# 19/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0270
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0363 - val_loss: 2.1496 - learning_rate: 0.0010
# Epoch 27/300
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0363 - val_loss: 2.1496 - learning_rate: 0.0010
# Epoch 27/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0108 - val_loss: 2.0953 - learning_rate: 5.0000e-04
# Epoch 28/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0108 - val_loss: 2.0953 - learning_rate: 5.0000e-04
# Epoch 28/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9569 - val_loss: 2.1216 - learning_rate: 5.0000e-04
# Epoch 29/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9569 - val_loss: 2.1216 - learning_rate: 5.0000e-04
# Epoch 29/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0050 - val_loss: 2.1205 - learning_rate: 5.0000e-04
# Epoch 30/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0050 - val_loss: 2.1205 - learning_rate: 5.0000e-04
# Epoch 30/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0230 - val_loss: 2.1614 - learning_rate: 5.0000e-04
# Epoch 31/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0230 - val_loss: 2.1614 - learning_rate: 5.0000e-04
# Epoch 31/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9583 - val_loss: 2.1233 - learning_rate: 5.0000e-04
# Epoch 32/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9583 - val_loss: 2.1233 - learning_rate: 5.0000e-04
# Epoch 32/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9876 - val_loss: 2.1402 - learning_rate: 5.0000e-04
# Epoch 33/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9876 - val_loss: 2.1402 - learning_rate: 5.0000e-04
# Epoch 33/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0000 - val_loss: 2.1583 - learning_rate: 5.0000e-04
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0000 - val_loss: 2.1583 - learning_rate: 5.0000e-04
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9390 - val_loss: 2.1748 - learning_rate: 5.0000e-04
# Epoch 35/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9390 - val_loss: 2.1748 - learning_rate: 5.0000e-04
# Epoch 35/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9686 - val_loss: 2.2054 - learning_rate: 5.0000e-04
# Epoch 36/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9686 - val_loss: 2.2054 - learning_rate: 5.0000e-04
# Epoch 36/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0223 - val_loss: 2.1646 - learning_rate: 5.0000e-04
# Epoch 37/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0223 - val_loss: 2.1646 - learning_rate: 5.0000e-04
# Epoch 37/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0106 - val_loss: 2.1532 - learning_rate: 5.0000e-04
# Epoch 38/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0106 - val_loss: 2.1532 - learning_rate: 5.0000e-04
# Epoch 38/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9856 - val_loss: 2.2288 - learning_rate: 5.0000e-04
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9856 - val_loss: 2.2288 - learning_rate: 5.0000e-04
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9348 - val_loss: 2.1240 - learning_rate: 5.0000e-04
# Epoch 40/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9348 - val_loss: 2.1240 - learning_rate: 5.0000e-04
# Epoch 40/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0434 - val_loss: 2.2103 - learning_rate: 5.0000e-04
# Epoch 41/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0434 - val_loss: 2.2103 - learning_rate: 5.0000e-04
# Epoch 41/300
# 17/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9459
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9563 - val_loss: 2.1953 - learning_rate: 5.0000e-04
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9563 - val_loss: 2.1953 - learning_rate: 5.0000e-04

# %% [markdown]
# ## Avaliação do Modelo
#
# Calcule MAE, RMSE e R² para o modelo GRU multivariado.

# %%
metrics = evaluate_model(
    model=model,
    X_test=X_test,
    y_test=y_test,
    scaler=scaler
)

print("Métricas de Avaliação:")
print(f"MAE: {metrics['mae']:.4f}")
print(f"RMSE: {metrics['rmse']:.4f}")
print(f"R²: {metrics['r2']:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Métricas de Avaliação:
# MAE: 50.5986
# RMSE: 68.7731
# R²: 0.5663
# Métricas de Avaliação:
# MAE: 50.5986
# RMSE: 68.7731
# R²: 0.5663

# %% [markdown]
# ## Visualização dos Resultados
#
# Plote os valores reais versus previstos e o erro de previsão. O alvo é a **soma das próximas 4 semanas** (previsão mensal).

# %%
def reduce_to_1d(arr):
    arr = np.asarray(arr)
    if arr.ndim == 1:
        return arr
    if arr.ndim == 2:
        if arr.shape[1] == 1:
            return arr.ravel()
        else:
            return arr.sum(axis=1)
    raise ValueError(f"Unexpected array shape: {arr.shape}")

# Always define robust 1D, denormalized arrays for all plots and DataFrames
y_test_1d = reduce_to_1d(y_test)
y_pred = generate_forecasts(model, X_test)  # Removed scaler argument
y_pred_1d = reduce_to_1d(y_pred)
if scaler is not None and hasattr(scaler, 'scale_') and hasattr(scaler, 'mean_'):
    if scaler.scale_.shape[0] > 1:
        y_test_1d = y_test_1d * scaler.scale_[0] + scaler.mean_[0]
        y_pred_1d = y_pred_1d * scaler.scale_[0] + scaler.mean_[0]
    else:
        y_test_1d = scaler.inverse_transform(y_test_1d.reshape(-1, 1)).flatten()
        y_pred_1d = scaler.inverse_transform(y_pred_1d.reshape(-1, 1)).flatten()

test_dates = test_df['week'].values[-len(y_test_1d):] if 'week' in test_df.columns else np.arange(len(y_test_1d))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
def reduce_to_1d(arr):
    arr = np.asarray(arr)
    if arr.ndim == 1:
        return arr
    if arr.ndim == 2:
        if arr.shape[1] == 1:
            return arr.ravel()
        else:
            return arr.sum(axis=1)
    raise ValueError(f"Unexpected array shape: {arr.shape}")

# Always define robust 1D, denormalized arrays for all plots and DataFrames
y_test_1d = reduce_to_1d(y_test)
y_pred = generate_forecasts(model, X_test)
y_pred_1d = reduce_to_1d(y_pred)
if scaler is not None and hasattr(scaler, 'scale_') and hasattr(scaler, 'mean_'):
    if scaler.scale_.shape[0] > 1:
        y_test_1d = y_test_1d * scaler.scale_[0] + scaler.mean_[0]
        y_pred_1d = y_pred_1d * scaler.scale_[0] + scaler.mean_[0]
    else:
        y_test_1d = scaler.inverse_transform(y_test_1d.reshape(-1, 1)).flatten()
        y_pred_1d = scaler.inverse_transform(y_pred_1d.reshape(-1, 1)).flatten()

# Get time axis for the test set
# Use 'week' if available, else integer index
if 'week' in test_df.columns:
    test_dates = test_df['week'].values[-len(y_test):]
else:
    test_dates = np.arange(len(y_test))

# Previsões
y_pred = generate_forecasts(model, X_test)

# 1. Forecast vs Actual
fig1 = plot_forecast(y_test, y_pred, dates=test_df['week'][-len(y_test):], title="Forecast vs Actual")
fig1.show()

# 2. Forecast Error
fig2 = plot_forecast_error(y_test, y_pred, dates=test_df['week'][-len(y_test):], title="Forecast Error")
fig2.show()

# 3. Distribution of Errors
errors = y_pred_1d - y_test_1d  # Ensure errors is 1D
plt.figure(figsize=(10,6))
sns.histplot(errors, kde=True, bins=30, color='crimson')
plt.title('Distribution of Forecast Errors')
plt.xlabel('Error (Predicted - Actual)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# 4. Scatter Plot: Actual vs Predicted
plt.figure(figsize=(8,8))
plt.scatter(y_test_1d, y_pred_1d, alpha=0.5)
plt.plot([y_test_1d.min(), y_test_1d.max()], [y_test_1d.min(), y_test_1d.max()], 'k--', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Scatter')
plt.grid(True)
plt.show()

# 5. Residuals Over Time
plt.figure(figsize=(12,6))
plt.plot(test_dates, errors, marker='o', linestyle='-', color='orange')
plt.axhline(0, color='black', linestyle='--')
plt.title('Residuals Over Time')
plt.xlabel('Week')
plt.ylabel('Residual (Predicted - Actual)')
plt.grid(True)
plt.show()

# 6. Rolling Mean of Errors
window = 8
rolling_error = pd.Series(errors).rolling(window=window).mean()
plt.figure(figsize=(12,6))
plt.plot(test_dates, rolling_error, color='purple')
plt.title(f'Rolling Mean of Errors (window={window})')
plt.xlabel('Week')
plt.ylabel('Rolling Mean Error')
plt.grid(True)
plt.show()

# 7. Cumulative Error
cumulative_error = np.cumsum(errors)
plt.figure(figsize=(12,6))
plt.plot(test_dates, cumulative_error, color='teal')
plt.title('Cumulative Forecast Error')
plt.xlabel('Week')
plt.ylabel('Cumulative Error')
plt.grid(True)
plt.show()

# 8. Feature Correlation Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df_city.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# 9. Target Distribution
plt.figure(figsize=(10,6))
sns.histplot(df_city['target'], kde=True, bins=30, color='royalblue')
plt.title('Target Distribution')
plt.xlabel('Target')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# 10. Missing Values Heatmap
plt.figure(figsize=(12,4))
sns.heatmap(df_city.isnull(), cbar=False, yticklabels=False)
plt.title('Missing Values Heatmap')
plt.show()

# Overlay plot: Série semanal real e soma prevista das 4 semanas
plt.figure(figsize=(14,6))
plt.plot(test_df['week'], test_df['target'], label='Semanal Real', color='gray', alpha=0.5)
plt.scatter(test_df['week'].values[-len(y_pred):], y_pred, label='Previsto (soma 4 semanas)', color='crimson', zorder=3)
plt.scatter(test_df['week'].values[-len(y_test):], y_test, label='Real (soma 4 semanas)', color='royalblue', marker='x', zorder=3)
plt.title('Série Semanal Real vs. Soma Prevista das 4 Semanas (Mensal)')
plt.xlabel('Semana')
plt.ylabel('Taxa de Morbidade Respiratória')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Diagnóstico: Verificar alinhamento de y_test e y_pred
N = 10
week_idx = test_dates[:N]
df_diag = pd.DataFrame({
    'week': week_idx,
    'y_test (soma 4 sem)': y_test_1d[:N],
    'y_pred (soma 4 sem)': y_pred_1d[:N]
})
display(df_diag)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# C:\Users\pedro\AppData\Local\Temp\ipykernel_32404\2257846503.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_32404\2257846503.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()
#    week  y_test (soma 4 sem)  y_pred (soma 4 sem)
# 0  1163           219.855000           167.373167
# 1  1164           253.666565           187.891198
# 2  1165           249.009526           226.785619
# 3  1166           252.523883           267.260714
# 4  1167           271.855000           329.204719
# 5  1168           301.740406           362.665461
# 6  1169           330.766515           342.941625
# 7  1170           353.508928           322.646811
# 8  1171           392.855000           342.055742
# 9  1172           439.400460           363.285564

# %% [markdown]
# ## Salvar Resultados
#
# Salve as previsões e métricas para comparação posterior.

# %%
# Salvar previsões
preds_file = save_predictions(
    y_true=y_test,
    y_pred=y_pred,
    dates=test_dates,
    city_name='São Paulo',
    model_name='gru_multivariate',
    output_dir=results_dir
)
print(f"Previsões salvas em: {preds_file}")

# Salvar métricas
metrics_file = save_metrics(
    metrics=metrics,
    city_name='São Paulo',
    model_name='gru_multivariate',
    output_dir=results_dir,
    params=model_params
)
print(f"Métricas salvas em: {metrics_file}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Salvar previsões
# ----> 2 preds_file = save_predictions(
#       3     y_true=y_test,
#       4     y_pred=y_pred,
#       5     dates=test_dates,
#       6     city_name='São Paulo',
#       7     model_name='gru_multivariate',
#       8     output_dir=results_dir
#       9 )
#      10 print(f"Previsões salvas em: {preds_file}")
#      12 # Salvar métricas
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models\src\train.py:98, in save_predictions(y_true, y_pred, dates, city_name, model_name, output_dir)
#      94 """
#      95 Save predictions to CSV.
#      96 """
#      97 import pandas as pd
# ---> 98 df = pd.DataFrame({'date': dates, 'y_true': y_true, 'y_pred': y_pred})
#      99 out_path = os.path.join(output_dir, f'{city_name}_{model_name}_preds.csv')
#     100 df.to_csv(out_path, index=False)
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\internals\construction.py:664, in _extract_index(data)
#     662         raw_lengths.append(len(val))
#     663     elif isinstance(val, np.ndarray) and val.ndim > 1:
# --> 664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
#     667     raise ValueError("If using all scalar values, you must pass an index")
#
# ValueError: Per-column arrays must each be 1-dimensional

# %% [markdown]
# ## Conclusão
#
# O modelo GRU multivariado permite incorporar variáveis externas relevantes. Compare seu desempenho com outros modelos nos próximos notebooks.
