# %% [markdown]
# # MLP – Rede Neural Feedforward (Soma das Próximas 4 Semanas)
#
# Este notebook implementa o modelo MLP (Multi-Layer Perceptron) para previsão da **soma das próximas 4 semanas** (previsão mensal) das taxas de morbidade respiratória em municípios brasileiros.
#
# - **Modelo:** MLP Feedforward
# - **Alvo:** Soma das próximas 4 semanas (previsão mensal)
# - **Input:** vetor com 8 semanas (shape: [batch, 8])
# - **Arquitetura:** Dense(32, ReLU) → Dense(1)
# - **Normalização:** Z-score
# - **Perda:** MAE
# - **Todo o código é modular e importado dos módulos `src/`.**

# %%
import sys
import os

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"Project root: {project_root}")

# Add the project root to sys.path (not the src directory)
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"Added {project_root} to sys.path")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from src.preprocessing import load_city_data, prepare_data_for_model, filter_city, clean_timeseries
from src.models import build_mlp
from src.train import train_model, evaluate_model, generate_forecasts, save_predictions, save_metrics
from src.utils import plot_forecast, plot_forecast_error, plot_training_history

results_dir = os.path.join('results', 'mlp_feedforward')
os.makedirs(results_dir, exist_ok=True)

np.random.seed(42)
# Out:
# Project root: c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models
# Added c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models to sys.path

# %% [markdown]
# ## Estrutura do Repositório
#
# - **data/**: Um CSV por cidade, cada um com coluna de data, coluna alvo e features opcionais.
# - **notebooks/**: Notebooks para cada experimento. Apenas visualização e exploração.
# - **src/**: Módulos reutilizáveis:
#     - `preprocessing.py`: Carregamento, normalização, split, criação de janelas
#     - `models.py`: Definições de modelos (baselines, MLP, LSTM, etc.)
#     - `train.py`: Rotinas de treino e avaliação
#     - `utils.py`: Funções auxiliares (plot, métricas, etc.)
# - **results/**: Previsões e métricas salvas.
# - **instructions.md**: Guia de boas práticas.
#
# **Toda a lógica central está em `src/`.**

# %% [markdown]
# ## Carregamento e Exploração dos Dados
#
# Carregue os dados de morbidade respiratória para análise. Você pode iterar sobre todas as cidades ou selecionar uma específica.

# %%
# Exemplo: Carregar dados de uma cidade (ajuste o caminho conforme necessário)
data_path = '../data/df_base_morb_resp.csv'
df = load_city_data(data_path)

print(f"Formato do dataset: {df.shape}")
df.head()
# Out:
# Formato do dataset: (6684000, 11)
#     CD_MUN  week    target      PIB      DENS       URB         CO2  \
# 0  1100015     0  0.515856  3469.14  3.541043  0.000611  550.985905
# 1  1100015     1  0.539765  3469.14  3.541043  0.000611  550.985905
# 2  1100015     2  0.458823  3469.14  3.541043  0.000611  550.985905
# 3  1100015     3  0.485555  3469.14  3.541043  0.000611  550.985905
# 4  1100015     4  0.231805  3469.14  3.541043  0.000611  550.985905
#
#          CH4       N2O        LAT    LON
# 0  92.946598  6.657747 -12.883213 -62.39
# 1  92.946598  6.657747 -12.883213 -62.39
# 2  92.946598  6.657747 -12.883213 -62.39
# 3  92.946598  6.657747 -12.883213 -62.39
# 4  92.946598  6.657747 -12.883213 -62.39

# %%
print("Colunas disponíveis:")
print(df.columns.tolist())
df.describe()
# Out:
# Colunas disponíveis:
# ['CD_MUN', 'week', 'target', 'PIB', 'DENS', 'URB', 'CO2', 'CH4', 'N2O', 'LAT', 'LON']
#              CD_MUN          week        target           PIB          DENS  \
# count  6.684000e+06  6.684000e+06  6.684000e+06  6.003816e+06  6.033600e+06
# mean   3.253591e+06  5.995000e+02  4.710729e-01  1.397299e+04  8.091379e+01
# std    9.848220e+05  3.464101e+02  3.616928e+00  1.973538e+04  3.952444e+02
# min    1.100015e+06  0.000000e+00  0.000000e+00 -1.459830e+03  3.143629e-02
# 25%    2.512101e+06  2.997500e+02  0.000000e+00  4.516650e+03  1.112562e+01
# 50%    3.146280e+06  5.995000e+02  0.000000e+00  8.607535e+03  2.363456e+01
# 75%    4.119202e+06  8.992500e+02  2.773210e-01  1.684539e+04  4.817254e+01
# max    5.300108e+06  1.199000e+03  7.359496e+02  9.208340e+05  1.344249e+04
#
#                 URB           CO2           CH4           N2O           LAT  \
# count  6.033600e+06  6.033600e+06  6.033600e+06  6.033600e+06  6.033600e+06
# mean   1.268524e-02  3.953797e+04  7.463403e+02  1.116126e+01 -1.638302e+01
# std    4.668693e-02  1.244388e+05  1.332048e+04  2.845796e+01  8.354524e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -3.365254e+01
# 25%    1.319166e-03  4.454221e+03  6.922971e+01  4.712564e+00 -2.279264e+01
# 50%    2.999792e-03  1.128696e+04  1.379897e+02  8.660524e+00 -1.785337e+01
# 75%    7.148583e-03  2.817704e+04  2.405503e+02  1.352129e+01 -8.456431e+00
# max    9.768962e-01  3.137265e+06  7.075641e+05  3.683565e+03  4.685425e+00
#
#                 LON
# count  6.033600e+06
# mean  -4.637996e+01
# std    6.424812e+00
# min   -7.348400e+01
# 25%   -5.102275e+01
# 50%   -4.661550e+01
# 75%   -4.166000e+01
# max   -3.487000e+01

# %% [markdown]
# ## Seleção e Limpeza de Cidade
#
# Selecione uma cidade específica para modelagem e limpe a série temporal.

# %%
# Select city for modeling (set to None to use all cities)
CD_MUN_SELECTED = 3550308  # São Paulo

df_city = filter_city(df, cd_mun=CD_MUN_SELECTED)
df_city = clean_timeseries(df_city, target_column='target')
print(f"Selected city shape: {df_city.shape}")
# Out:
# Selected city shape: (1200, 11)

# %% [markdown]
# ## Pré-processamento
#
# Prepare os dados para o modelo MLP. O input é um vetor de 8 semanas.

# %%
model_params = {
    'sequence_length': 8,
    'forecast_horizon': 4,  # Soma das próximas 4 semanas (previsão mensal)
    'normalization': 'zscore',
    'val_size': None
}
target_column = 'target'

data_dict = prepare_data_for_model(
    df=df_city,
    target_column=target_column,
    sequence_length=model_params['sequence_length'],
    forecast_horizon=model_params['forecast_horizon'],
    normalization=model_params['normalization'],
    val_size=model_params.get('val_size', None)
)

X_train = data_dict['X_train']
y_train = data_dict['y_train']
X_val = data_dict.get('X_val', None)
y_val = data_dict.get('y_val', None)
X_test = data_dict['X_test']
y_test = data_dict['y_test']
test_df = data_dict['test_df']
scaler = data_dict.get('scaler')
feature_columns = data_dict.get('feature_columns', None)

# Para MLP, "achate" a entrada para [batch, 8]
X_train = X_train.reshape(X_train.shape[0], -1)
if X_val is not None:
    X_val = X_val.reshape(X_val.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %% [markdown]
# ## Definição e Treinamento do Modelo
#
# O modelo MLP utiliza uma camada densa de 32 unidades (ReLU) e uma camada densa de saída.

# %%
input_shape = X_train.shape[1:]
model = build_mlp(input_shape=input_shape, units=32)

history = train_model(
    model=model,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    batch_size=32,
    epochs=300,
    patience=30,
    verbose=1
)
# Out:
# Epoch 1/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0680 - val_loss: 2.2630 - learning_rate: 0.0010
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.0680 - val_loss: 2.2630 - learning_rate: 0.0010
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6978 - val_loss: 2.2491 - learning_rate: 0.0010
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6978 - val_loss: 2.2491 - learning_rate: 0.0010
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5517 - val_loss: 2.2314 - learning_rate: 0.0010
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5517 - val_loss: 2.2314 - learning_rate: 0.0010
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3754 - val_loss: 2.2264 - learning_rate: 0.0010
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3754 - val_loss: 2.2264 - learning_rate: 0.0010
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4306 - val_loss: 2.1632 - learning_rate: 0.0010
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4306 - val_loss: 2.1632 - learning_rate: 0.0010
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2112 - val_loss: 2.1184 - learning_rate: 0.0010
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2112 - val_loss: 2.1184 - learning_rate: 0.0010
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3048 - val_loss: 2.0602 - learning_rate: 0.0010
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3048 - val_loss: 2.0602 - learning_rate: 0.0010
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3112 - val_loss: 1.9721 - learning_rate: 0.0010
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3112 - val_loss: 1.9721 - learning_rate: 0.0010
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1719 - val_loss: 1.9922 - learning_rate: 0.0010
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1719 - val_loss: 1.9922 - learning_rate: 0.0010
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1152 - val_loss: 1.9261 - learning_rate: 0.0010
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1152 - val_loss: 1.9261 - learning_rate: 0.0010
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1560 - val_loss: 1.9045 - learning_rate: 0.0010
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1560 - val_loss: 1.9045 - learning_rate: 0.0010
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1146 - val_loss: 1.8776 - learning_rate: 0.0010
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1146 - val_loss: 1.8776 - learning_rate: 0.0010
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1930 - val_loss: 1.8837 - learning_rate: 0.0010
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1930 - val_loss: 1.8837 - learning_rate: 0.0010
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1577 - val_loss: 1.9067 - learning_rate: 0.0010
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1577 - val_loss: 1.9067 - learning_rate: 0.0010
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1653 - val_loss: 1.9594 - learning_rate: 0.0010
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1653 - val_loss: 1.9594 - learning_rate: 0.0010
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1130 - val_loss: 1.9096 - learning_rate: 0.0010
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1130 - val_loss: 1.9096 - learning_rate: 0.0010
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1431 - val_loss: 1.9041 - learning_rate: 0.0010
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1431 - val_loss: 1.9041 - learning_rate: 0.0010
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1534 - val_loss: 1.9948 - learning_rate: 0.0010
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1534 - val_loss: 1.9948 - learning_rate: 0.0010
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1426 - val_loss: 1.9214 - learning_rate: 0.0010
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1426 - val_loss: 1.9214 - learning_rate: 0.0010
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1232 - val_loss: 1.9245 - learning_rate: 0.0010
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1232 - val_loss: 1.9245 - learning_rate: 0.0010
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0553 - val_loss: 1.9330 - learning_rate: 0.0010
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0553 - val_loss: 1.9330 - learning_rate: 0.0010
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1046 - val_loss: 1.9332 - learning_rate: 0.0010
# Epoch 23/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1046 - val_loss: 1.9332 - learning_rate: 0.0010
# Epoch 23/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0587 - val_loss: 1.9476 - learning_rate: 0.0010
# Epoch 24/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0587 - val_loss: 1.9476 - learning_rate: 0.0010
# Epoch 24/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0875 - val_loss: 1.9431 - learning_rate: 0.0010
# Epoch 25/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0875 - val_loss: 1.9431 - learning_rate: 0.0010
# Epoch 25/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0729 - val_loss: 1.9389 - learning_rate: 0.0010
# Epoch 26/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0729 - val_loss: 1.9389 - learning_rate: 0.0010
# Epoch 26/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0988 - val_loss: 1.9333 - learning_rate: 0.0010
# Epoch 27/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0988 - val_loss: 1.9333 - learning_rate: 0.0010
# Epoch 27/300
#  1/32 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2114
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1255 - val_loss: 1.9205 - learning_rate: 0.0010
# Epoch 28/300
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1255 - val_loss: 1.9205 - learning_rate: 0.0010
# Epoch 28/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1207 - val_loss: 1.9360 - learning_rate: 5.0000e-04
# Epoch 29/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1207 - val_loss: 1.9360 - learning_rate: 5.0000e-04
# Epoch 29/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1082 - val_loss: 1.9483 - learning_rate: 5.0000e-04
# Epoch 30/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1082 - val_loss: 1.9483 - learning_rate: 5.0000e-04
# Epoch 30/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0427 - val_loss: 1.9328 - learning_rate: 5.0000e-04
# Epoch 31/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0427 - val_loss: 1.9328 - learning_rate: 5.0000e-04
# Epoch 31/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0334 - val_loss: 1.9363 - learning_rate: 5.0000e-04
# Epoch 32/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0334 - val_loss: 1.9363 - learning_rate: 5.0000e-04
# Epoch 32/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0620 - val_loss: 1.9328 - learning_rate: 5.0000e-04
# Epoch 33/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0620 - val_loss: 1.9328 - learning_rate: 5.0000e-04
# Epoch 33/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1397 - val_loss: 1.9567 - learning_rate: 5.0000e-04
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1397 - val_loss: 1.9567 - learning_rate: 5.0000e-04
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0303 - val_loss: 1.9593 - learning_rate: 5.0000e-04
# Epoch 35/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0303 - val_loss: 1.9593 - learning_rate: 5.0000e-04
# Epoch 35/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0416 - val_loss: 1.9532 - learning_rate: 5.0000e-04
# Epoch 36/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0416 - val_loss: 1.9532 - learning_rate: 5.0000e-04
# Epoch 36/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0704 - val_loss: 1.9379 - learning_rate: 5.0000e-04
# Epoch 37/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0704 - val_loss: 1.9379 - learning_rate: 5.0000e-04
# Epoch 37/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0015 - val_loss: 1.9521 - learning_rate: 5.0000e-04
# Epoch 38/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0015 - val_loss: 1.9521 - learning_rate: 5.0000e-04
# Epoch 38/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0539 - val_loss: 1.9905 - learning_rate: 5.0000e-04
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0539 - val_loss: 1.9905 - learning_rate: 5.0000e-04
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1024 - val_loss: 1.9789 - learning_rate: 5.0000e-04
# Epoch 40/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1024 - val_loss: 1.9789 - learning_rate: 5.0000e-04
# Epoch 40/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0394 - val_loss: 1.9904 - learning_rate: 5.0000e-04
# Epoch 41/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0394 - val_loss: 1.9904 - learning_rate: 5.0000e-04
# Epoch 41/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0613 - val_loss: 1.9608 - learning_rate: 5.0000e-04
# Epoch 42/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0613 - val_loss: 1.9608 - learning_rate: 5.0000e-04
# Epoch 42/300
#  1/32 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2869
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1145 - val_loss: 2.0451 - learning_rate: 5.0000e-04
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1145 - val_loss: 2.0451 - learning_rate: 5.0000e-04

# %% [markdown]
# ## Avaliação do Modelo
#
# Calcule MAE, RMSE e R² para o modelo MLP.

# %%
metrics = evaluate_model(
    model=model,
    X_test=X_test,
    y_test=y_test,
    scaler=scaler
)

print("Métricas de Avaliação:")
print(f"MAE: {metrics['mae']:.4f}")
print(f"RMSE: {metrics['rmse']:.4f}")
print(f"R²: {metrics['r2']:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Métricas de Avaliação:
# MAE: 54.7524
# RMSE: 71.7807
# R²: 0.6621
# Métricas de Avaliação:
# MAE: 54.7524
# RMSE: 71.7807
# R²: 0.6621

# %% [markdown]
# ## Visualização dos Resultados
#
# Plote os valores reais versus previstos e o erro de previsão. O alvo é a **soma das próximas 4 semanas** (previsão mensal).

# %%
def reduce_to_1d(arr):
    arr = np.asarray(arr)
    if arr.ndim == 1:
        return arr
    if arr.ndim == 2:
        if arr.shape[1] == 1:
            return arr.ravel()
        else:
            return arr.sum(axis=1)
    raise ValueError(f"Unexpected array shape: {arr.shape}")

# Always define robust 1D, denormalized arrays for all plots and DataFrames
y_test_1d = reduce_to_1d(y_test)
y_pred = generate_forecasts(model, X_test)
y_pred_1d = reduce_to_1d(y_pred)
if scaler is not None and hasattr(scaler, 'scale_') and hasattr(scaler, 'mean_'):
    if scaler.scale_.shape[0] > 1:
        y_test_1d = y_test_1d * scaler.scale_[0] + scaler.mean_[0]
        y_pred_1d = y_pred_1d * scaler.scale_[0] + scaler.mean_[0]
    else:
        y_test_1d = scaler.inverse_transform(y_test_1d.reshape(-1, 1)).flatten()
        y_pred_1d = scaler.inverse_transform(y_pred_1d.reshape(-1, 1)).flatten()

test_dates = test_df['week'].values[-len(y_test_1d):] if 'week' in test_df.columns else np.arange(len(y_test_1d))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
def reduce_to_1d(arr):
    arr = np.asarray(arr)
    if arr.ndim == 1:
        return arr
    if arr.ndim == 2:
        if arr.shape[1] == 1:
            return arr.ravel()
        else:
            return arr.sum(axis=1)
    raise ValueError(f"Unexpected array shape: {arr.shape}")

# Always define robust 1D, denormalized arrays for all plots and DataFrames
y_test_1d = reduce_to_1d(y_test)
y_pred = generate_forecasts(model, X_test)
y_pred_1d = reduce_to_1d(y_pred)
if scaler is not None and hasattr(scaler, 'scale_') and hasattr(scaler, 'mean_'):
    if scaler.scale_.shape[0] > 1:
        y_test_1d = y_test_1d * scaler.scale_[0] + scaler.mean_[0]
        y_pred_1d = y_pred_1d * scaler.scale_[0] + scaler.mean_[0]
    else:
        y_test_1d = scaler.inverse_transform(y_test_1d.reshape(-1, 1)).flatten()
        y_pred_1d = scaler.inverse_transform(y_pred_1d.reshape(-1, 1)).flatten()

# Get time axis for the test set
# Use 'week' if available, else integer index
if 'week' in test_df.columns:
    test_dates = test_df['week'].values[-len(y_test):]
else:
    test_dates = np.arange(len(y_test))

# Previsões
y_pred = generate_forecasts(model, X_test)

# 1. Forecast vs Actual
fig1 = plot_forecast(y_test, y_pred, dates=test_dates, title="Forecast vs Actual")
fig1.show()

# 2. Forecast Error
fig2 = plot_forecast_error(y_test, y_pred, dates=test_dates, title="Forecast Error")
fig2.show()

# 3. Distribution of Errors
errors = y_pred - y_test
plt.figure(figsize=(10,6))
sns.histplot(errors, kde=True, bins=30, color='crimson')
plt.title('Distribution of Forecast Errors')
plt.xlabel('Error (Predicted - Actual)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# 4. Scatter Plot: Actual vs Predicted
plt.figure(figsize=(8,8))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Scatter')
plt.grid(True)
plt.show()

# 5. Residuals Over Time
plt.figure(figsize=(12,6))
plt.plot(test_dates, errors, marker='o', linestyle='-', color='orange')
plt.axhline(0, color='black', linestyle='--')
plt.title('Residuals Over Time')
plt.xlabel('Week')
plt.ylabel('Residual (Predicted - Actual)')
plt.grid(True)
plt.show()

# 6. Rolling Mean of Errors
window = 8
rolling_error = pd.Series(errors).rolling(window=window).mean()
plt.figure(figsize=(12,6))
plt.plot(test_dates, rolling_error, color='purple')
plt.title(f'Rolling Mean of Errors (window={window})')
plt.xlabel('Week')
plt.ylabel('Rolling Mean Error')
plt.grid(True)
plt.show()

# 7. Cumulative Error
cumulative_error = np.cumsum(errors)
plt.figure(figsize=(12,6))
plt.plot(test_dates, cumulative_error, color='teal')
plt.title('Cumulative Forecast Error')
plt.xlabel('Week')
plt.ylabel('Cumulative Error')
plt.grid(True)
plt.show()

# 8. Feature Correlation Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df_city.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# 9. Target Distribution
plt.figure(figsize=(10,6))
sns.histplot(df_city['target'], kde=True, bins=30, color='royalblue')
plt.title('Target Distribution')
plt.xlabel('Target')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# 10. Missing Values Heatmap
plt.figure(figsize=(12,4))
sns.heatmap(df_city.isnull(), cbar=False, yticklabels=False)
plt.title('Missing Values Heatmap')
plt.show()

# Overlay plot: Série semanal real e soma prevista das 4 semanas
plt.figure(figsize=(14,6))
plt.plot(test_df['week'], test_df['target'], label='Semanal Real', color='gray', alpha=0.5)
plt.scatter(test_df['week'].values[-len(y_pred):], y_pred, label='Previsto (soma 4 semanas)', color='crimson', zorder=3)
plt.scatter(test_df['week'].values[-len(y_test):], y_test, label='Real (soma 4 semanas)', color='royalblue', marker='x', zorder=3)
plt.title('Série Semanal Real vs. Soma Prevista das 4 Semanas (Mensal)')
plt.xlabel('Semana')
plt.ylabel('Taxa de Morbidade Respiratória')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Diagnóstico: Verificar alinhamento de y_test e y_pred
import pandas as pd
N = 10
week_idx = test_df['week'].values[-len(y_test):]
df_diag = pd.DataFrame({
    'week': week_idx[:N],
    'y_test (soma 4 sem)': y_test[:N],
    'y_pred (soma 4 sem)': y_pred[:N]
})
display(df_diag)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\pedro\AppData\Local\Temp\ipykernel_33656\2932282015.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_33656\2932282015.py:40: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 74
#      72 # 6. Rolling Mean of Errors
#      73 window = 8
# ---> 74 rolling_error = pd.Series(errors).rolling(window=window).mean()
#      75 plt.figure(figsize=(12,6))
#      76 plt.plot(test_dates, rolling_error, color='purple')
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\construction.py:659, in sanitize_array(data, index, dtype, copy, allow_2d)
#     656             subarr = cast(np.ndarray, subarr)
#     657             subarr = maybe_infer_to_datetimelike(subarr)
# --> 659 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     661 if isinstance(subarr, np.ndarray):
#     662     # at this point we should have dtype be None or subarr.dtype == dtype
#     663     dtype = cast(np.dtype, dtype)
#
# File c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\treinamento_clusters_hpc\.conda\lib\site-packages\pandas\core\construction.py:718, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     716     if allow_2d:
#     717         return result
# --> 718     raise ValueError(
#     719         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     720     )
#     721 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     722     # i.e. NumpyEADtype("O")
#     724     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (41, 41) instead

# %% [markdown]
# ## Salvar Resultados
#
# Salve as previsões e métricas para comparação posterior.

# %%
# Salvar previsões
y_test_1d = np.asarray(y_test).ravel() if hasattr(y_test, 'ndim') and y_test.ndim > 1 else y_test
# y_pred_1d is already defined above for plots, but ensure it's 1D here
y_pred_1d = np.asarray(y_pred).ravel() if hasattr(y_pred, 'ndim') and y_pred.ndim > 1 else y_pred
preds_file = save_predictions(
    y_true=y_test_1d,
    y_pred=y_pred_1d,
    dates=test_dates,
    city_name='São Paulo',
    model_name='mlp_feedforward',
    output_dir=results_dir
)
print(f"Previsões salvas em: {preds_file}")

# Salvar métricas
metrics_file = save_metrics(
    metrics=metrics,
    city_name='São Paulo',
    model_name='mlp_feedforward',
    output_dir=results_dir,
    params=model_params
)
print(f"Métricas salvas em: {metrics_file}")
# Out:
# Previsões salvas em: results\mlp_feedforward\São Paulo_mlp_feedforward_preds.csv
# Métricas salvas em: results\mlp_feedforward\São Paulo_mlp_feedforward_metrics.csv

# %% [markdown]
# ## Conclusão
#
# O modelo MLP serve como baseline neural simples para previsão de morbidade respiratória semanal. Compare seu desempenho com outros modelos nos próximos notebooks.
