# %% [markdown]
# # CNN + GRU (Soma das Próximas 4 Semanas)
#
# Este notebook implementa o modelo CNN + GRU para previsão da **soma das próximas 4 semanas** (previsão mensal) das taxas de morbidade respiratória em municípios brasileiros.
#
# - **Modelo:** CNN + GRU
# - **Alvo:** Soma das próximas 4 semanas (previsão mensal)
# - **Input:** sequência de 24 semanas (shape: [batch, 24, 1])
# - **Arquitetura:** Conv1D(32, kernel_size=3, activation=ReLU) → MaxPooling1D() → GRU(32) → Dense(1)
# - **Perda:** MAE
# - **Todo o código é modular e importado dos módulos `src/`.**

# %%
import sys
import os

# Get the absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
print(f"Project root: {project_root}")

# Add the project root to sys.path (not the src directory)
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    print(f"Added {project_root} to sys.path")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from src.preprocessing import load_city_data, prepare_data_for_model, filter_city, clean_timeseries
from src.models import build_cnn_gru
from src.train import train_model, evaluate_model, generate_forecasts, save_predictions, save_metrics
from src.utils import plot_forecast, plot_forecast_error, plot_training_history

results_dir = os.path.join('results', 'cnn_gru')
os.makedirs(results_dir, exist_ok=True)

np.random.seed(42)
# Out:
# Project root: c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models
# Added c:\Users\pedro\OneDrive - Unesp\Documentos\GitHub\cities-models\cities-models to sys.path

# %% [markdown]
# ## Estrutura do Repositório
#
# - **data/**: Um CSV por cidade, cada um com coluna de data, coluna alvo e features opcionais.
# - **notebooks/**: Notebooks para cada experimento. Apenas visualização e exploração.
# - **src/**: Módulos reutilizáveis:
#     - `preprocessing.py`: Carregamento, normalização, split, criação de janelas
#     - `models.py`: Definições de modelos (baselines, MLP, LSTM, etc.)
#     - `train.py`: Rotinas de treino e avaliação
#     - `utils.py`: Funções auxiliares (plot, métricas, etc.)
# - **results/**: Previsões e métricas salvas.
# - **instructions.md**: Guia de boas práticas.
#
# **Toda a lógica central está em `src/`.**

# %% [markdown]
# ## Carregamento e Exploração dos Dados
#
# Carregue os dados de morbidade respiratória para análise. Você pode iterar sobre todas as cidades ou selecionar uma específica.

# %%
# Exemplo: Carregar dados de uma cidade (ajuste o caminho conforme necessário)
data_path = '../data/df_base_morb_resp.csv'
df = load_city_data(data_path)

print(f"Formato do dataset: {df.shape}")
df.head()
# Out:
# Formato do dataset: (6684000, 11)
#     CD_MUN  week    target      PIB      DENS       URB         CO2  \
# 0  1100015     0  0.515856  3469.14  3.541043  0.000611  550.985905
# 1  1100015     1  0.539765  3469.14  3.541043  0.000611  550.985905
# 2  1100015     2  0.458823  3469.14  3.541043  0.000611  550.985905
# 3  1100015     3  0.485555  3469.14  3.541043  0.000611  550.985905
# 4  1100015     4  0.231805  3469.14  3.541043  0.000611  550.985905
#
#          CH4       N2O        LAT    LON
# 0  92.946598  6.657747 -12.883213 -62.39
# 1  92.946598  6.657747 -12.883213 -62.39
# 2  92.946598  6.657747 -12.883213 -62.39
# 3  92.946598  6.657747 -12.883213 -62.39
# 4  92.946598  6.657747 -12.883213 -62.39

# %%
print("Colunas disponíveis:")
print(df.columns.tolist())
df.describe()
# Out:
# Colunas disponíveis:
# ['CD_MUN', 'week', 'target', 'PIB', 'DENS', 'URB', 'CO2', 'CH4', 'N2O', 'LAT', 'LON']
#              CD_MUN          week        target           PIB          DENS  \
# count  6.684000e+06  6.684000e+06  6.684000e+06  6.003816e+06  6.033600e+06
# mean   3.253591e+06  5.995000e+02  4.710729e-01  1.397299e+04  8.091379e+01
# std    9.848220e+05  3.464101e+02  3.616928e+00  1.973538e+04  3.952444e+02
# min    1.100015e+06  0.000000e+00  0.000000e+00 -1.459830e+03  3.143629e-02
# 25%    2.512101e+06  2.997500e+02  0.000000e+00  4.516650e+03  1.112562e+01
# 50%    3.146280e+06  5.995000e+02  0.000000e+00  8.607535e+03  2.363456e+01
# 75%    4.119202e+06  8.992500e+02  2.773210e-01  1.684539e+04  4.817254e+01
# max    5.300108e+06  1.199000e+03  7.359496e+02  9.208340e+05  1.344249e+04
#
#                 URB           CO2           CH4           N2O           LAT  \
# count  6.033600e+06  6.033600e+06  6.033600e+06  6.033600e+06  6.033600e+06
# mean   1.268524e-02  3.953797e+04  7.463403e+02  1.116126e+01 -1.638302e+01
# std    4.668693e-02  1.244388e+05  1.332048e+04  2.845796e+01  8.354524e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -3.365254e+01
# 25%    1.319166e-03  4.454221e+03  6.922971e+01  4.712564e+00 -2.279264e+01
# 50%    2.999792e-03  1.128696e+04  1.379897e+02  8.660524e+00 -1.785337e+01
# 75%    7.148583e-03  2.817704e+04  2.405503e+02  1.352129e+01 -8.456431e+00
# max    9.768962e-01  3.137265e+06  7.075641e+05  3.683565e+03  4.685425e+00
#
#                 LON
# count  6.033600e+06
# mean  -4.637996e+01
# std    6.424812e+00
# min   -7.348400e+01
# 25%   -5.102275e+01
# 50%   -4.661550e+01
# 75%   -4.166000e+01
# max   -3.487000e+01

# %% [markdown]
# ## Seleção e Limpeza de Cidade
#
# Selecione uma cidade específica para modelagem e limpe a série temporal.

# %%
# Select city for modeling (set to None to use all cities)
CD_MUN_SELECTED = 3550308  # São Paulo

df_city = filter_city(df, cd_mun=CD_MUN_SELECTED)
df_city = clean_timeseries(df_city, target_column='target')
print(f"Selected city shape: {df_city.shape}")
# Out:
# Selected city shape: (1200, 11)

# %% [markdown]
# ## Pré-processamento
#
# Prepare os dados para o modelo CNN + GRU. O input é uma sequência de 24 semanas.

# %%
# Set the correct target column
model_params = {
    'sequence_length': 12,
    'forecast_horizon': 4,  # Soma das próximas 4 semanas (previsão mensal)
    'normalization': 'zscore',
    'val_size': None
}
target_column = 'target'

data_dict = prepare_data_for_model(
    df=df_city,
    target_column=target_column,
    sequence_length=model_params['sequence_length'],
    forecast_horizon=model_params['forecast_horizon'],
    normalization=model_params['normalization'],
    val_size=model_params.get('val_size', None)
)

X_train = data_dict['X_train']
y_train = data_dict['y_train']
X_val = data_dict.get('X_val', None)
y_val = data_dict.get('y_val', None)
X_test = data_dict['X_test']
y_test = data_dict['y_test']
test_df = data_dict['test_df']
scaler = data_dict.get('scaler')
feature_columns = data_dict.get('feature_columns', None)

# %% [markdown]
# ## Definição e Treinamento do Modelo
#
# O modelo CNN + GRU utiliza uma camada convolucional seguida de pooling e GRU.

# %%
input_shape = X_train.shape[1:]
model = build_cnn_gru(input_shape=input_shape, loss='mae')

history = train_model(
    model=model,
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    batch_size=32,
    epochs=300,
    patience=30,
    verbose=1
)
# Out:
# Epoch 1/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3181 - val_loss: 2.3951 - learning_rate: 0.0010
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3181 - val_loss: 2.3951 - learning_rate: 0.0010
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8227 - val_loss: 2.2534 - learning_rate: 0.0010
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8227 - val_loss: 2.2534 - learning_rate: 0.0010
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7367 - val_loss: 2.2595 - learning_rate: 0.0010
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7367 - val_loss: 2.2595 - learning_rate: 0.0010
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4620 - val_loss: 2.1930 - learning_rate: 0.0010
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4620 - val_loss: 2.1930 - learning_rate: 0.0010
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4081 - val_loss: 2.0877 - learning_rate: 0.0010
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4081 - val_loss: 2.0877 - learning_rate: 0.0010
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2533 - val_loss: 2.0168 - learning_rate: 0.0010
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2533 - val_loss: 2.0168 - learning_rate: 0.0010
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2910 - val_loss: 1.9617 - learning_rate: 0.0010
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2910 - val_loss: 1.9617 - learning_rate: 0.0010
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2020 - val_loss: 1.9497 - learning_rate: 0.0010
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2020 - val_loss: 1.9497 - learning_rate: 0.0010
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1624 - val_loss: 1.9123 - learning_rate: 0.0010
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1624 - val_loss: 1.9123 - learning_rate: 0.0010
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2286 - val_loss: 1.9070 - learning_rate: 0.0010
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2286 - val_loss: 1.9070 - learning_rate: 0.0010
# Epoch 11/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1941 - val_loss: 1.8922 - learning_rate: 0.0010
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1941 - val_loss: 1.8922 - learning_rate: 0.0010
# Epoch 12/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0984 - val_loss: 1.8782 - learning_rate: 0.0010
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0984 - val_loss: 1.8782 - learning_rate: 0.0010
# Epoch 13/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1568 - val_loss: 1.9104 - learning_rate: 0.0010
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1568 - val_loss: 1.9104 - learning_rate: 0.0010
# Epoch 14/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1523 - val_loss: 1.9091 - learning_rate: 0.0010
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1523 - val_loss: 1.9091 - learning_rate: 0.0010
# Epoch 15/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1759 - val_loss: 1.9167 - learning_rate: 0.0010
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1759 - val_loss: 1.9167 - learning_rate: 0.0010
# Epoch 16/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1692 - val_loss: 1.9282 - learning_rate: 0.0010
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1692 - val_loss: 1.9282 - learning_rate: 0.0010
# Epoch 17/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1307 - val_loss: 1.9396 - learning_rate: 0.0010
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1307 - val_loss: 1.9396 - learning_rate: 0.0010
# Epoch 18/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1749 - val_loss: 1.9167 - learning_rate: 0.0010
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1749 - val_loss: 1.9167 - learning_rate: 0.0010
# Epoch 19/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1496 - val_loss: 1.9638 - learning_rate: 0.0010
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1496 - val_loss: 1.9638 - learning_rate: 0.0010
# Epoch 20/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1016 - val_loss: 2.0415 - learning_rate: 0.0010
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1016 - val_loss: 2.0415 - learning_rate: 0.0010
# Epoch 21/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1075 - val_loss: 1.9563 - learning_rate: 0.0010
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1075 - val_loss: 1.9563 - learning_rate: 0.0010
# Epoch 22/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0195 - val_loss: 1.9924 - learning_rate: 0.0010
# Epoch 23/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0195 - val_loss: 1.9924 - learning_rate: 0.0010
# Epoch 23/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0471 - val_loss: 1.9594 - learning_rate: 0.0010
# Epoch 24/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0471 - val_loss: 1.9594 - learning_rate: 0.0010
# Epoch 24/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0423 - val_loss: 1.9651 - learning_rate: 0.0010
# Epoch 25/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0423 - val_loss: 1.9651 - learning_rate: 0.0010
# Epoch 25/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1333 - val_loss: 2.0168 - learning_rate: 0.0010
# Epoch 26/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1333 - val_loss: 2.0168 - learning_rate: 0.0010
# Epoch 26/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0405 - val_loss: 2.0150 - learning_rate: 0.0010
# Epoch 27/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0405 - val_loss: 2.0150 - learning_rate: 0.0010
# Epoch 27/300
# 22/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1146
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0907 - val_loss: 2.0568 - learning_rate: 0.0010
# Epoch 28/300
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0907 - val_loss: 2.0568 - learning_rate: 0.0010
# Epoch 28/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0243 - val_loss: 2.0851 - learning_rate: 5.0000e-04
# Epoch 29/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0243 - val_loss: 2.0851 - learning_rate: 5.0000e-04
# Epoch 29/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0470 - val_loss: 2.1122 - learning_rate: 5.0000e-04
# Epoch 30/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0470 - val_loss: 2.1122 - learning_rate: 5.0000e-04
# Epoch 30/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0435 - val_loss: 2.0791 - learning_rate: 5.0000e-04
# Epoch 31/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0435 - val_loss: 2.0791 - learning_rate: 5.0000e-04
# Epoch 31/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9859 - val_loss: 2.1048 - learning_rate: 5.0000e-04
# Epoch 32/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9859 - val_loss: 2.1048 - learning_rate: 5.0000e-04
# Epoch 32/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0930 - val_loss: 2.1253 - learning_rate: 5.0000e-04
# Epoch 33/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0930 - val_loss: 2.1253 - learning_rate: 5.0000e-04
# Epoch 33/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9751 - val_loss: 2.1505 - learning_rate: 5.0000e-04
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9751 - val_loss: 2.1505 - learning_rate: 5.0000e-04
# Epoch 34/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9663 - val_loss: 2.1088 - learning_rate: 5.0000e-04
# Epoch 35/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9663 - val_loss: 2.1088 - learning_rate: 5.0000e-04
# Epoch 35/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9978 - val_loss: 2.1482 - learning_rate: 5.0000e-04
# Epoch 36/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9978 - val_loss: 2.1482 - learning_rate: 5.0000e-04
# Epoch 36/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0326 - val_loss: 2.1953 - learning_rate: 5.0000e-04
# Epoch 37/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0326 - val_loss: 2.1953 - learning_rate: 5.0000e-04
# Epoch 37/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9466 - val_loss: 2.1707 - learning_rate: 5.0000e-04
# Epoch 38/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9466 - val_loss: 2.1707 - learning_rate: 5.0000e-04
# Epoch 38/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0771 - val_loss: 2.2105 - learning_rate: 5.0000e-04
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0771 - val_loss: 2.2105 - learning_rate: 5.0000e-04
# Epoch 39/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8962 - val_loss: 2.1966 - learning_rate: 5.0000e-04
# Epoch 40/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8962 - val_loss: 2.1966 - learning_rate: 5.0000e-04
# Epoch 40/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0361 - val_loss: 2.1325 - learning_rate: 5.0000e-04
# Epoch 41/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0361 - val_loss: 2.1325 - learning_rate: 5.0000e-04
# Epoch 41/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9804 - val_loss: 2.1904 - learning_rate: 5.0000e-04
# Epoch 42/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9804 - val_loss: 2.1904 - learning_rate: 5.0000e-04
# Epoch 42/300
# 15/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9708
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0027 - val_loss: 2.2007 - learning_rate: 5.0000e-04
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0027 - val_loss: 2.2007 - learning_rate: 5.0000e-04

# %% [markdown]
# ## Avaliação do Modelo
#
# Calcule MAE, RMSE e R² para o modelo CNN + GRU.

# %%
metrics = evaluate_model(
    model=model,
    X_test=X_test,
    y_test=y_test,
    scaler=scaler
)

print("Métricas de Avaliação:")
print(f"MAE: {metrics['mae']:.4f}")
print(f"RMSE: {metrics['rmse']:.4f}")
print(f"R²: {metrics['r2']:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Métricas de Avaliação:
# MAE: 53.4656
# RMSE: 66.6821
# R²: 0.5923
# Métricas de Avaliação:
# MAE: 53.4656
# RMSE: 66.6821
# R²: 0.5923

# %% [markdown]
# ## Visualização dos Resultados
#
# Plote os valores reais versus previstos e o erro de previsão. O alvo é a **soma das próximas 4 semanas** (previsão mensal).

# %%
def reduce_to_1d(arr):
    arr = np.asarray(arr)
    if arr.ndim == 1:
        return arr
    if arr.ndim == 2:
        if arr.shape[1] == 1:
            return arr.ravel()
        else:
            return arr.sum(axis=1)
    raise ValueError(f"Unexpected array shape: {arr.shape}")

# Always define robust 1D, denormalized arrays for all plots and DataFrames
y_test_1d = reduce_to_1d(y_test)
y_pred = generate_forecasts(model, X_test)
y_pred_1d = reduce_to_1d(y_pred)
if scaler is not None and hasattr(scaler, 'scale_') and hasattr(scaler, 'mean_'):
    if scaler.scale_.shape[0] > 1:
        y_test_1d = y_test_1d * scaler.scale_[0] + scaler.mean_[0]
        y_pred_1d = y_pred_1d * scaler.scale_[0] + scaler.mean_[0]
    else:
        y_test_1d = scaler.inverse_transform(y_test_1d.reshape(-1, 1)).flatten()
        y_pred_1d = scaler.inverse_transform(y_pred_1d.reshape(-1, 1)).flatten()

test_dates = test_df['week'].values[-len(y_test_1d):] if 'week' in test_df.columns else np.arange(len(y_test_1d))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
def reduce_to_1d(arr):
    arr = np.asarray(arr)
    if arr.ndim == 1:
        return arr
    if arr.ndim == 2:
        if arr.shape[1] == 1:
            return arr.ravel()
        else:
            return arr.sum(axis=1)
    raise ValueError(f"Unexpected array shape: {arr.shape}")

# Always define robust 1D, denormalized arrays for all plots and DataFrames
y_test_1d = reduce_to_1d(y_test)
y_pred = generate_forecasts(model, X_test)
y_pred_1d = reduce_to_1d(y_pred)
if scaler is not None and hasattr(scaler, 'scale_') and hasattr(scaler, 'mean_'):
    if scaler.scale_.shape[0] > 1:
        y_test_1d = y_test_1d * scaler.scale_[0] + scaler.mean_[0]
        y_pred_1d = y_pred_1d * scaler.scale_[0] + scaler.mean_[0]
    else:
        y_test_1d = scaler.inverse_transform(y_test_1d.reshape(-1, 1)).flatten()
        y_pred_1d = scaler.inverse_transform(y_pred_1d.reshape(-1, 1)).flatten()

# --- Advanced Evaluation and Visualization ---

# 1. Forecast vs Actual
fig1 = plot_forecast(y_test_1d, y_pred_1d, dates=test_dates, title="Forecast vs Actual")
fig1.show()

# 2. Forecast Error
fig2 = plot_forecast_error(y_test_1d, y_pred_1d, dates=test_dates, title="Forecast Error")
fig2.show()

# 3. Distribution of Errors
errors = y_pred_1d - y_test_1d
plt.figure(figsize=(10,6))
sns.histplot(errors, kde=True, bins=30, color='crimson')
plt.title('Distribution of Forecast Errors')
plt.xlabel('Error (Predicted - Actual)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# 4. Scatter Plot: Actual vs Predicted
plt.figure(figsize=(8,8))
plt.scatter(y_test_1d, y_pred_1d, alpha=0.5)
plt.plot([y_test_1d.min(), y_test_1d.max()], [y_test_1d.min(), y_test_1d.max()], 'k--', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Scatter')
plt.grid(True)
plt.show()

# 5. Residuals Over Time
plt.figure(figsize=(12,6))
plt.plot(test_dates, errors, marker='o', linestyle='-', color='orange')
plt.axhline(0, color='black', linestyle='--')
plt.title('Residuals Over Time')
plt.xlabel('Week')
plt.ylabel('Residual (Predicted - Actual)')
plt.grid(True)
plt.show()

# 6. Rolling Mean of Errors
window = 8
rolling_error = pd.Series(errors).rolling(window=window).mean()
plt.figure(figsize=(12,6))
plt.plot(test_dates, rolling_error, color='purple')
plt.title(f'Rolling Mean of Errors (window={window})')
plt.xlabel('Week')
plt.ylabel('Rolling Mean Error')
plt.grid(True)
plt.show()

# 7. Cumulative Error
cumulative_error = np.cumsum(errors)
plt.figure(figsize=(12,6))
plt.plot(test_dates, cumulative_error, color='teal')
plt.title('Cumulative Forecast Error')
plt.xlabel('Week')
plt.ylabel('Cumulative Error')
plt.grid(True)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# C:\Users\pedro\AppData\Local\Temp\ipykernel_29044\1439336457.py:28: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig1.show()
# C:\Users\pedro\AppData\Local\Temp\ipykernel_29044\1439336457.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig2.show()

# %% [markdown]
# ## Salvar Resultados
#
# Salve as previsões e métricas para comparação posterior.

# %%
# Salvar previsões
preds_file = save_predictions(
    y_true=y_test_1d,
    y_pred=y_pred_1d,
    dates=test_dates,
    city_name='São Paulo',
    model_name='cnn_gru',
    output_dir=results_dir
)
print(f"Previsões salvas em: {preds_file}")

# Salvar métricas
metrics_file = save_metrics(
    metrics=metrics,
    city_name='São Paulo',
    model_name='cnn_gru',
    output_dir=results_dir,
    params=model_params
)
print(f"Métricas salvas em: {metrics_file}")
# Out:
# Previsões salvas em: results\cnn_gru\São Paulo_cnn_gru_preds.csv
# Métricas salvas em: results\cnn_gru\São Paulo_cnn_gru_metrics.csv

# %% [markdown]
# ## Conclusão
#
# O modelo CNN + GRU permite capturar padrões temporais e espaciais. Compare seu desempenho com outros modelos nos próximos notebooks.
